# %%
import pandas as pd
import numpy as np
import io
import requests

# Assuming the file is a Google Sheet, export it to CSV format
# Replace 'csv' with other formats if needed (e.g., 'xlsx' for Excel)
# Update the URL to point to your specific file
url = "https://docs.google.com/spreadsheets/d/16g2H16w9FlV7OKAPv2i7u7dPcyvMGIo_/export?format=csv"
response = requests.get(url)

# Read the CSV data into a pandas DataFrame
df = pd.read_csv(io.StringIO(response.text), on_bad_lines='skip') # Skip bad lines if any

df
# Out:
#        Unnamed: 0   S.NO  Patient ID              IPNO  \
# 0             NaN      1     2967005  202310_001828783
# 1             NaN      2     2872700  202209_001759985
# 2             NaN      3     2289886  201512_001160841
# 3             NaN      4     2272612  201510_001139078
# 4             NaN      5    21540495  202108_001670602
# ...           ...    ...         ...               ...
# 12964         NaN  12965     2803059  202309_001824929
# 12965         NaN  12966     2107197  201808_001450668
# 12966         NaN  12967    21247277  201812_001480430
# 12967         NaN  12968     2974683  202311_001832400
# 12968         NaN  12969    20632323  201510_001142122
#
#                     Patient Name  Age Year Gender     Ward Dateof Admission  \
# 0       ABIVIGNESHWARA KANAGARAJ   32  YRS      M       D4       10/17/2023
# 1                ARYA MUTHU   R     7  YRS      M       A3        9/23/2022
# 2                    HEMASUNDARI   11  YRS      F       F7       12/26/2015
# 3                  LAKSHMIDHAR D    9  YRS      M       B3        10/9/2015
# 4                  MAHESHWARAN A   16  YRS      M  NB-PAED         8/9/2021
# ...                          ...  ...  ...    ...      ...              ...
# 12964                 ZAYAN KHAN    1  YRS      M       B3        9/17/2023
# 12965           ZEENA  GOPAKUMAR   47  YRS      F       D4        8/30/2018
# 12966                 ZEENATH A    39  YRS      F   NB-FMW        12/9/2018
# 12967           ZEENATH AFRIN  M   16  YRS      F       B3       11/17/2023
# 12968                     ZUBEER    4  YRS      M  NB-PAED       10/20/2015
#
#        ... Diagonisis Description.6 Diagonisis Description.7  \
# 0      ...                      NaN                      NaN
# 1      ...                      NaN                      NaN
# 2      ...                      NaN                      NaN
# 3      ...                      NaN                      NaN
# 4      ...                      NaN                      NaN
# ...    ...                      ...                      ...
# 12964  ...                      NaN                      NaN
# 12965  ...                      NaN                      NaN
# 12966  ...                      NaN                      NaN
# 12967  ...                      NaN                      NaN
# 12968  ...                      NaN                      NaN
#
#       Diagonisis Description.8 Diagonisis Description.9  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 12964                      NaN                      NaN
# 12965                      NaN                      NaN
# 12966                      NaN                      NaN
# 12967                      NaN                      NaN
# 12968                      NaN                      NaN
#
#       Diagonisis Description.10 Diagonisis Description.11  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 12964                       NaN                       NaN
# 12965                       NaN                       NaN
# 12966                       NaN                       NaN
# 12967                       NaN                       NaN
# 12968                       NaN                       NaN
#
#       Diagonisis Description.12 Diagonisis Description.13  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 12964                       NaN                       NaN
# 12965                       NaN                       NaN
# 12966                       NaN                       NaN
# 12967                       NaN                       NaN
# 12968                       NaN                       NaN
#
#       Diagonisis Description.14 Diagonisis Description.15
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 12964                       NaN                       NaN
# 12965                       NaN                       NaN
# 12966                       NaN                       NaN
# 12967                       NaN                       NaN
# 12968                       NaN                       NaN
#
# [12969 rows x 33 columns]

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12969 entries, 0 to 12968
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 0 non-null      float64
#  1   S.NO                       12969 non-null  int64
#  2   Patient ID                 12969 non-null  int64
#  3   IPNO                       12969 non-null  object
#  4   Patient Name               12969 non-null  object
#  5   Age                        12969 non-null  int64
#  6   Year                       12969 non-null  object
#  7   Gender                     12969 non-null  object
#  8   Ward                       12969 non-null  object
#  9   Dateof Admission           12969 non-null  object
#  10  Dateof Discharge           12969 non-null  object
#  11  DOCNAME                    12615 non-null  object
#  12  Status                     12968 non-null  object
#  13  PStreet Name               12969 non-null  object
#  14  PArea Name                 12968 non-null  object
#  15  PPhone                     12969 non-null  object
#  16  PMobile                    12969 non-null  object
#  17  Diagonisis Description     12969 non-null  object
#  18  Diagonisis Description.1   12969 non-null  object
#  19  Diagonisis Description.2   6176 non-null   object
#  20  Diagonisis Description.3   6176 non-null   object
#  21  Diagonisis Description.4   2315 non-null   object
#  22  Diagonisis Description.5   2316 non-null   object
#  23  Diagonisis Description.6   961 non-null    object
#  24  Diagonisis Description.7   961 non-null    object
#  25  Diagonisis Description.8   384 non-null    object
#  26  Diagonisis Description.9   385 non-null    object
#  27  Diagonisis Description.10  167 non-null    object
#  28  Diagonisis Description.11  167 non-null    object
#  29  Diagonisis Description.12  73 non-null     object
#  30  Diagonisis Description.13  73 non-null     object
#  31  Diagonisis Description.14  38 non-null     object
#  32  Diagonisis Description.15  38 non-null     object
# dtypes: float64(1), int64(3), object(29)
# memory usage: 3.3+ MB
#        Unnamed: 0          S.NO    Patient ID           Age
# count         0.0  12969.000000  1.296900e+04  12969.000000
# mean          NaN   6485.000000  1.053437e+07     23.275812
# std           NaN   3743.972155  9.267520e+06     15.647303
# min           NaN      1.000000  3.349170e+05      1.000000
# 25%           NaN   3243.000000  2.451816e+06     11.000000
# 50%           NaN   6485.000000  2.881982e+06     21.000000
# 75%           NaN   9727.000000  2.102704e+07     32.000000
# max           NaN  12969.000000  2.179056e+07     90.000000

# %%
df.head(4)
# Out:
#    Unnamed: 0  S.NO  Patient ID              IPNO               Patient Name  \
# 0         NaN     1     2967005  202310_001828783   ABIVIGNESHWARA KANAGARAJ
# 1         NaN     2     2872700  202209_001759985            ARYA MUTHU   R
# 2         NaN     3     2289886  201512_001160841                HEMASUNDARI
# 3         NaN     4     2272612  201510_001139078              LAKSHMIDHAR D
#
#    Age Year Gender Ward Dateof Admission  ... Diagonisis Description.6  \
# 0   32  YRS      M   D4       10/17/2023  ...                      NaN
# 1    7  YRS      M   A3        9/23/2022  ...                      NaN
# 2   11  YRS      F   F7       12/26/2015  ...                      NaN
# 3    9  YRS      M   B3        10/9/2015  ...                      NaN
#
#   Diagonisis Description.7 Diagonisis Description.8 Diagonisis Description.9  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
#
#   Diagonisis Description.10 Diagonisis Description.11  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
#
#   Diagonisis Description.12 Diagonisis Description.13  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
#
#   Diagonisis Description.14 Diagonisis Description.15
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
#
# [4 rows x 33 columns]

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_') #Rename Columns (if needed)

# %%
df.isnull().sum() #missing values
# Out:
# unnamed:_0                   12969
# s.no                             0
# patient_id                       0
# ipno                             0
# patient_name                     0
# age                              0
# year                             0
# gender                           0
# ward                             0
# dateof_admission                 0
# dateof_discharge                 0
# docname                        354
# status                           1
# pstreet_name                     0
# parea_name                       1
# pphone                           0
# pmobile                          0
# diagonisis_description           0
# diagonisis_description.1         0
# diagonisis_description.2      6793
# diagonisis_description.3      6793
# diagonisis_description.4     10654
# diagonisis_description.5     10653
# diagonisis_description.6     12008
# diagonisis_description.7     12008
# diagonisis_description.8     12585
# diagonisis_description.9     12584
# diagonisis_description.10    12802
# diagonisis_description.11    12802
# diagonisis_description.12    12896
# diagonisis_description.13    12896
# diagonisis_description.14    12931
# diagonisis_description.15    12931
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [unnamed:_0, s.no, patient_id, ipno, patient_name, age, year, gender, ward, dateof_admission, dateof_discharge, docname, status, pstreet_name, parea_name, pphone, pmobile, diagonisis_description, diagonisis_description.1, diagonisis_description.2, diagonisis_description.3, diagonisis_description.4, diagonisis_description.5, diagonisis_description.6, diagonisis_description.7, diagonisis_description.8, diagonisis_description.9, diagonisis_description.10, diagonisis_description.11, diagonisis_description.12, diagonisis_description.13, diagonisis_description.14, diagonisis_description.15]
# Index: []
#
# [0 rows x 33 columns]

# %%
# Fix year if incorrectly formatted
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# One-hot encode categorical variables
df = pd.get_dummies(df, columns=['gender', 'ward', 'status'], drop_first=True)

# %%
df.drop(columns=['patient_id', 'ipno', 'patient_name', 'pstreet_name', 'pphone', 'pmobile'], inplace=True)

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
print(missing)
# Out:
# unnamed:_0                   12969
# year                         12969
# docname                        354
# parea_name                       1
# diagonisis_description.2      6793
# diagonisis_description.3      6793
# diagonisis_description.4     10654
# diagonisis_description.5     10653
# diagonisis_description.6     12008
# diagonisis_description.7     12008
# diagonisis_description.8     12585
# diagonisis_description.9     12584
# diagonisis_description.10    12802
# diagonisis_description.11    12802
# diagonisis_description.12    12896
# diagonisis_description.13    12896
# diagonisis_description.14    12931
# diagonisis_description.15    12931
# dtype: int64

# %%
# Convert 'dateof_discharge' and 'dateof_admission' to datetime objects
df['dateof_discharge'] = pd.to_datetime(df['dateof_discharge'], errors='coerce')
df['dateof_admission'] = pd.to_datetime(df['dateof_admission'], errors='coerce')

# Now calculate stay_length
df['stay_length'] = (df['dateof_discharge'] - df['dateof_admission']).dt.days
df['admission_month'] = df['dateof_admission'].dt.month
df['admission_season'] = df['admission_month'] % 12 // 3 + 1  # 1: Winter, 2: Spring, etc.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numerical_cols = ['age', 'stay_length']  # Add more if needed
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
import os #Import the os module

# Create the directory if it doesn't exist
os.makedirs('/mnt/data', exist_ok=True)

# Now save the DataFrame to CSV
df.to_csv('/mnt/data/cleaned_dengue_cases.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Choose relevant numerical features
numerical_cols = ['age', 'stay_length']  # Add more if applicable

# Plot box plots
plt.figure(figsize=(12, 6))
for i, col in enumerate(numerical_cols):
    plt.subplot(1, len(numerical_cols), i+1)
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
# Example: Age vs Stay Length
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='stay_length', data=df)
plt.title('Scatter plot: Age vs Stay Length')
plt.xlabel('Age')
plt.ylabel('Length of Stay (days)')
plt.grid(True)
plt.show()

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    filtered_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return filtered_df

# %%
# Columns suspected to have outliers
outlier_columns = ['age', 'stay_length']

# Remove outliers sequentially
for col in outlier_columns:
    df = remove_outliers_iqr(df, col)

# %%
print("Data shape after removing outliers:", df.shape)
print(df[outlier_columns].describe())
# Out:
# Data shape after removing outliers: (12432, 87)
#                 age   stay_length
# count  12432.000000  12432.000000
# mean      -0.059747      0.012112
# std        0.913705      0.002895
# min       -1.423675      0.007165
# 25%       -0.784562      0.010865
# 50%       -0.145450      0.010865
# 75%        0.493662      0.014565
# max        2.538822      0.020114

# %%
df.to_csv('/mnt/data/dengue_data_no_outliers.csv', index=False)

# %%
# Ensure date is in datetime format #Temporal Trends (Yearly & Monthly Cases)
df['dateof_admission'] = pd.to_datetime(df['dateof_admission'], errors='coerce')

# Extract year and month
df['year'] = df['dateof_admission'].dt.year
df['month'] = df['dateof_admission'].dt.month

# Trend over years
plt.figure(figsize=(10, 5))
sns.countplot(x='year', data=df, palette='Blues_d')
plt.title('Dengue Cases per Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Monthly seasonality
plt.figure(figsize=(10, 5))
sns.countplot(x='month', data=df, palette='Oranges')
plt.title('Dengue Cases by Month')
plt.xticks(range(1,13))
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-43-6ad813663d8a>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='year', data=df, palette='Blues_d')
# <ipython-input-43-6ad813663d8a>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='month', data=df, palette='Oranges')

# %%
#Seasonality Patterns
df['season'] = df['month'] % 12 // 3 + 1  # 1: Winter, 2: Spring, etc.

plt.figure(figsize=(8, 5))
sns.countplot(x='season', data=df, palette='Set2')
plt.title('Dengue Cases by Season')
plt.xlabel('Season (1:Winter, 2:Spring, 3:Summer, 4:Fall)')
plt.show()
# Out:
# <ipython-input-44-c8c7d6d6bce3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='season', data=df, palette='Set2')

# %%
#Gender and Age Group Distribution
# Gender distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='gender_M', data=df)  # assuming one-hot encoding
plt.title('Gender Distribution of Dengue Cases')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Age Distribution of Dengue Patients')
plt.xlabel('Age')
plt.show()

# %%
#Length of Stay Trends
# Stay length vs month
plt.figure(figsize=(10, 6))
sns.boxplot(x='month', y='stay_length', data=df)
plt.title('Length of Stay per Month')
plt.xlabel('Month')
plt.ylabel('Days in Hospital')
plt.show()
